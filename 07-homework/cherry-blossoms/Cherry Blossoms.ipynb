# %% [markdown]
# # Cherry Blossoms!
#
# If we travel back in time a few months, [cherry blossoms](https://en.wikipedia.org/wiki/Cherry_blossom) were in full bloom! We don't live in Japan or DC, but we do have our fair share of the trees - buuut you sadly missed [Brooklyn Botanic Garden's annual festival](https://www.bbg.org/visit/event/sakura_matsuri_2019).
#
# We'll have to make up for it with data-driven cherry blossoms instead. Once upon a time [Data is Plural](https://tinyletter.com/data-is-plural) linked to [a dataset](http://atmenv.envi.osakafu-u.ac.jp/aono/kyophenotemp4/) about when the cherry trees blossom each year. It's a little out of date, but it's quirky in a real nice way so we're sticking with it.
#
# ## 0. Do all of your importing/setup stuff

# %%
import pandas as pd
import numpy as np


# %matplotlib inline

# %% [markdown]
# ## 1. Read in the file using pandas, and look at the first five rows

# %%
df = pd.read_excel('KyotoFullFlower7.xls')
df
# Out:
#      Full-flowering dates of Japanese cherry (Prunus jamasakura) at Kyoto, Japan. (Latest version, Jun. 12, 2012)  \
# 0     This phenological data was acquired by followi...
# 1                                                   NaN
# 2                                        Column A; A.D.
# 3          Column B; Full-flowering date (day of year).
# 4     Column C; Full-flowering date (calender date, ...
# 5                                 Column D; Source code
# 6      1; Reported by Taguchi (1939), J. Marine Mete...
# 7      2; Added by Sekiguchi (1969), Tokyo Geography...
# 8      3; Added by Aono and Omoto (1994), J. Agric. ...
# 9      4; Added by Aono and Kazui (2008), Int. J. Cl...
# 10     5: Cherry phenological data, Added by Aono an...
# 11     6: Added by Aono (2011), Time Studies, 4, 17-...
# 12     7: Added by Aono (2012), Chikyu Kankyo, 17, 2...
# 13     8: Found after the last publication of articles.
# 14                             Column E; Data type code
# ...

# %% [markdown]
# ## 2. Read in the file using pandas CORRECTLY, and look at the first five rows
#
# Hrm, how do your column names look? Read the file in again but this time add a parameter to make sure your columns look right.
#
# **TIP: The first year should be 801 AD, and it should not have any dates or anything.**

# %%
df = pd.read_excel('KyotoFullFlower7.xls', skiprows=25).dropna()
df
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 11     812                       92.0                401.0          1.0
# 14     815                      105.0                415.0          1.0
# 30     831                       96.0                406.0          1.0
# 50     851                      108.0                418.0          1.0
# 52     853                      104.0                414.0          1.0
# 63     864                      100.0                409.0          1.0
# 65     866                      106.0                416.0          1.0
# 68     869                       95.0                405.0          5.0
# 88     889                      104.0                414.0          5.0
# 90     891                      109.0                419.0          5.0
# 91     892                      108.0                417.0          5.0
# 93     894                      106.0                416.0          5.0
# ...

# %% [markdown]
# ## 3. Look at the final five rows of the data

# %%
df.tail(5)
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 1210  2011                       99.0                409.0          8.0
# 1211  2012                      101.0                410.0          8.0
# 1212  2013                       93.0                403.0          8.0
# 1213  2014                       94.0                404.0          8.0
# 1214  2015                       93.0                403.0          8.0
#
#       Data type code          Reference Name
# 1210             0.0  NEWS-PAPER(ARASHIYAMA)
# 1211             0.0  NEWS-PAPER(ARASHIYAMA)
# 1212             0.0  NEWS-PAPER(ARASHIYAMA)
# 1213             0.0  NEWS-PAPER(ARASHIYAMA)
# 1214             0.0  NEWS-PAPER(ARASHIYAMA)

# %% [markdown]
# ## 4. Add some more NaN values

# %% [markdown]
# It looks like you should probably have some NaN/missing values earlier on in the dataset under "Reference name." Read in the file *one more time*, this time making sure all of those missing reference names actually show up as `NaN` instead of `-`.

# %%
cherry_blossoms = df.rename(columns={
    'Reference Name': 'Reference_Name', 'Full-flowering date (DOY)':'Full_flowering_year','Full-flowering date':'Full_flowering_date', 'Data type code':'Data_type', 'Source code':'Source'})
cherry_blossoms
# Out:
#         AD  Full_flowering_year  Full_flowering_date  Source  Data_type  \
# 11     812                 92.0                401.0     1.0        2.0
# 14     815                105.0                415.0     1.0        2.0
# 30     831                 96.0                406.0     1.0        2.0
# 50     851                108.0                418.0     1.0        2.0
# 52     853                104.0                414.0     1.0        2.0
# 63     864                100.0                409.0     1.0        2.0
# 65     866                106.0                416.0     1.0        2.0
# 68     869                 95.0                405.0     5.0        2.0
# 88     889                104.0                414.0     5.0        2.0
# 90     891                109.0                419.0     5.0        4.0
# 91     892                108.0                417.0     5.0        3.0
# 93     894                106.0                416.0     5.0        2.0
# ...

# %%
cherry_blossoms.head()
# Out:
#      AD  Full_flowering_year  Full_flowering_date  Source  Data_type  \
# 11  812                 92.0                401.0     1.0        2.0
# 14  815                105.0                415.0     1.0        2.0
# 30  831                 96.0                406.0     1.0        2.0
# 50  851                108.0                418.0     1.0        2.0
# 52  853                104.0                414.0     1.0        2.0
#
#             Reference_Name
# 11              NIHON-KOKI
# 14              NIHON-KOKI
# 30              NIHON-KOKI
# 50  MONTOKUTENNO-JITSUROKU
# 52  MONTOKUTENNO-JITSUROKU

# %% [markdown]
# ## 4. What source is the most common as a reference?

# %% [markdown]
# ***Source that is most common as reference is News-Paper (Arashiyama)***

# %%
cherry_blossoms.Reference_Name.value_counts().sort_values(ascending=False).head(5)
# Out:
# NEWS-PAPER(ARASHIYAMA)    94
# SUGIURAKE-NIKKI           38
# MYOHOIN-HINAMIKI          32
# OYUDONONO-UENO-NIKKI      26
# DAIGOJI-ZATSUYO           21
# Name: Reference_Name, dtype: int64

# %% [markdown]
# ## 6. Filter the list to only include columns where the `Full-flowering date (DOY)` is not missing
#
# If you'd like to do it in two steps (which might be easier to think through), first figure out how to test whether a column is empty/missing/null/NaN, get the list of `True`/`False` values, and then later feed it to your `df`.

# %%
cherry_blossoms.Full_flowering_year.isna().value_counts()

#df.ABV.isna().value_counts()
# Out:
# False    825
# Name: Full_flowering_year, dtype: int64

# %%
#there is none null values

# %% [markdown]
# ## 7. Make a histogram of the full-flowering date
#
# Is it not showing up? Remember the "magic" command that makes graphs show up in matplotlib notebooks!

# %%
cherry_blossoms.Full_flowering_year.plot(kind='hist', alpha=0.5, color='purple', title ='Cherry Blossoms Full Flowering Date of Year')

# %% [markdown]
# ## 8. Make another histogram of the full-flowering date, but with 39 bins instead of 10

# %%
cherry_blossoms.Full_flowering_year.plot(kind='hist', bins=39, alpha=1, color='pink', title='Cherry Blossoms Full Flowering Date of Year')

# %% [markdown]
# ## 9. What's the average number of days it takes for the flowers to blossom? And how many records do we have?
#
# Answer these both with one line of code.

# %%
cherry_blossoms.dtypes
# Out:
# AD                       int64
# Full_flowering_year    float64
# Full_flowering_date    float64
# Source                 float64
# Data_type              float64
# Reference_Name          object
# dtype: object

# %%
av_blossoms = cherry_blossoms.Full_flowering_date.mean()
av_blossoms
# Out:
# 413.8169696969697

# %%
cherry_blossoms.Full_flowering_date.shape
# Out:
# (825,)

# %% [markdown]
# ## 10. What's the average days into the year cherry flowers normally blossomed before 1900?

# %%
cherry_blossoms.AD.sort_values(ascending=False).head(30)
# Out:
# 1214    2015
# 1213    2014
# 1212    2013
# 1211    2012
# 1210    2011
# 1209    2010
# 1208    2009
# 1207    2008
# 1206    2007
# 1205    2006
# 1204    2005
# 1203    2004
# 1202    2003
# 1201    2002
# 1200    2001
# 1199    2000
# 1198    1999
# 1197    1998
# 1196    1997
# 1195    1996
# 1194    1995
# 1193    1994
# 1192    1993
# 1191    1992
# 1190    1991
# 1189    1990
# 1188    1989
# 1187    1988
# 1186    1987
# 1185    1986
# Name: AD, dtype: int64

# %%
before_19 = cherry_blossoms[cherry_blossoms.AD <= 1900]
before_19
#df[df.Location =='Brooklyn, NY']
# Out:
#         AD  Full_flowering_year  Full_flowering_date  Source  Data_type  \
# 11     812                 92.0                401.0     1.0        2.0
# 14     815                105.0                415.0     1.0        2.0
# 30     831                 96.0                406.0     1.0        2.0
# 50     851                108.0                418.0     1.0        2.0
# 52     853                104.0                414.0     1.0        2.0
# 63     864                100.0                409.0     1.0        2.0
# 65     866                106.0                416.0     1.0        2.0
# 68     869                 95.0                405.0     5.0        2.0
# 88     889                104.0                414.0     5.0        2.0
# 90     891                109.0                419.0     5.0        4.0
# 91     892                108.0                417.0     5.0        3.0
# 93     894                106.0                416.0     5.0        2.0
# ...

# %%
before_19.Full_flowering_date.mean()
# Out:
# 414.50350631136047

# %% [markdown]
# ***The average days into the years cherry blossoms normally blossomed before 1990***

# %% [markdown]
# ## 11. How about after 1900?

# %%
after_19 = cherry_blossoms[cherry_blossoms.AD >= 1900]
after_19.Full_flowering_date.mean()
# Out:
# 409.46902654867256

# %% [markdown]
# ## 12. How many times was our data from a title in Japanese poetry?
#
# You'll need to read the documentation inside of the Excel file.

# %%
cherry_blossoms.Data_type
# Out:
# 11      2.0
# 14      2.0
# 30      2.0
# 50      2.0
# 52      2.0
# 63      2.0
# 65      2.0
# 68      2.0
# 88      2.0
# 90      4.0
# 91      3.0
# 93      2.0
# 94      4.0
# 95      4.0
# 101     8.0
# 107     8.0
# 111     2.0
# 112     2.0
# 116     2.0
# 122     4.0
# 125     2.0
# 129     8.0
# 132     8.0
# 140     2.0
# 148     2.0
# 149     2.0
# 154     4.0
# 156     2.0
# 157     2.0
# 158     2.0
#        ...
# 1185    0.0
# 1186    0.0
# 1187    0.0
# 1188    0.0
# 1189    0.0
# 1190    0.0
# 1191    0.0
# 1192    0.0
# 1193    0.0
# 1194    0.0
# 1195    0.0
# 1196    0.0
# 1197    0.0
# 1198    0.0
# 1199    0.0
# 1200    0.0
# 1201    0.0
# 1202    0.0
# 1203    0.0
# 1204    0.0
# 1205    0.0
# 1206    0.0
# 1207    0.0
# 1208    0.0
# 1209    0.0
# 1210    0.0
# 1211    0.0
# 1212    0.0
# 1213    0.0
# 1214    0.0
# Name: Data_type, Length: 825, dtype: float64

# %%
cherry_blossoms['Data_type'] = cherry_blossoms.Data_type.astype(int)
cherry_blossoms

#df['ABV'] = df.ABV.astype(float)
# Out:
#         AD  Full_flowering_year  Full_flowering_date  Source  Data_type  \
# 11     812                 92.0                401.0     1.0          2
# 14     815                105.0                415.0     1.0          2
# 30     831                 96.0                406.0     1.0          2
# 50     851                108.0                418.0     1.0          2
# 52     853                104.0                414.0     1.0          2
# 63     864                100.0                409.0     1.0          2
# 65     866                106.0                416.0     1.0          2
# 68     869                 95.0                405.0     5.0          2
# 88     889                104.0                414.0     5.0          2
# 90     891                109.0                419.0     5.0          4
# 91     892                108.0                417.0     5.0          3
# 93     894                106.0                416.0     5.0          2
# ...

# %%
cherry_blossoms.dtypes
# Out:
# AD                       int64
# Full_flowering_year    float64
# Full_flowering_date    float64
# Source                 float64
# Data_type                int64
# Reference_Name          object
# dtype: object

# %%
cherry_blossoms.head()
# Out:
#      AD  Full_flowering_year  Full_flowering_date  Source  Data_type  \
# 11  812                 92.0                401.0     1.0          2
# 14  815                105.0                415.0     1.0          2
# 30  831                 96.0                406.0     1.0          2
# 50  851                108.0                418.0     1.0          2
# 52  853                104.0                414.0     1.0          2
#
#             Reference_Name
# 11              NIHON-KOKI
# 14              NIHON-KOKI
# 30              NIHON-KOKI
# 50  MONTOKUTENNO-JITSUROKU
# 52  MONTOKUTENNO-JITSUROKU

# %%
japanese_title = cherry_blossoms[cherry_blossoms.Data_type == 4]
japanese_title
# Out:
#         AD  Full_flowering_year  Full_flowering_date  Source  Data_type  \
# 90     891                109.0                419.0     5.0          4
# 94     895                104.0                414.0     5.0          4
# 95     896                104.0                413.0     5.0          4
# 122    923                104.0                414.0     5.0          4
# 154    955                 89.0                330.0     5.0          4
# 168    969                 98.0                408.0     5.0          4
# 206   1007                106.0                416.0     5.0          4
# 232   1033                102.0                412.0     5.0          4
# 235   1036                104.0                413.0     5.0          4
# 259   1060                108.0                417.0     5.0          4
# 260   1061                 92.0                402.0     6.0          4
# 283   1084                120.0                429.0     5.0          4
# ...

# %%
japanese_title.Data_type.value_counts()
# Out:
# 4    39
# Name: Data_type, dtype: int64

# %% [markdown]
# ***The data was taken from a Japanese title for 39 times***

# %% [markdown]
# ## 13. Show only the years where our data was from a title in Japanese poetry

# %%
years_title = japanese_title.AD
years_title
# Out:
# 90       891
# 94       895
# 95       896
# 122      923
# 154      955
# 168      969
# 206     1007
# 232     1033
# 235     1036
# 259     1060
# 260     1061
# 283     1084
# 294     1095
# 381     1182
# 389     1190
# 400     1201
# 415     1216
# 418     1219
# 420     1221
# 422     1223
# 435     1236
# 464     1265
# 467     1268
# 468     1269
# 470     1271
# 488     1289
# 500     1301
# 523     1324
# 529     1330
# 646     1447
# 652     1453
# 653     1454
# 673     1474
# 733     1534
# 791     1592
# 839     1640
# 860     1661
# 1045    1846
# 1062    1863
# Name: AD, dtype: int64

# %% [markdown]
# ## 14. Graph the full-flowering date (DOY) over time

# %%
cherry_blossoms.Full_flowering_year.plot(kind='line', alpha=0.5, title='Full Flowering Year of Cherry Blossoms')

# %% [markdown]
# ## 15. Smooth out the graph
#
# It's so jagged! You can use `df.rolling` to calculate a rolling average.
#
# The following code calculates a **10-year mean**, using the `AD` column as the anchor. If there aren't 20 samples to work with in a row, it'll accept down to 5. Neat, right?
#
# (We're only looking at the final 5)

# %%
cherry_blossoms.rolling(10, on='AD', min_periods=5)['Full_flowering_year'].mean().tail(5)
# Out:
# 1210    95.9
# 1211    96.9
# 1212    96.4
# 1213    96.6
# 1214    96.0
# Name: Full_flowering_year, dtype: float64

# %%
cherry_blossoms['rolling_date']= cherry_blossoms.rolling(10, on='AD', min_periods=5)['Full_flowering_year'].mean().plot(kind='line', ylim=(80, 120), color='red', alpha=1, figsize=(10,3), title="Full Flowering Year of Cherry Blossoms")

# %% [markdown]
# Use the code above to create a new column called `rolling_date` in our dataset. It should be the 20-year rolling average of the flowering date. Then plot it, with the year on the x axis and the day of the year on the y axis.
#
# Try adding `ylim=(80, 120)` to your `.plot` command to make things look a little less dire.

# %% [markdown]
# ### 16. Add a month column
#
# Right now the "Full-flowering date" column is pretty rough. It uses numbers like '402' to mean "April 2nd" and "416" to mean "April 16th." Let's make a column to explain what month it happened in.
#
# * Every row that happened in April should have 'April' in the `month` column.
# * Every row that happened in March should have 'March' as the `month` column.
# * Every row that happened in May should have 'May' as the `month` column.
#
# **I've given you March as an example**, you just need to add in two more lines to do April and May.

# %%
cherry_blossoms
# Out:
#         AD  Full_flowering_year  Full_flowering_date  Source  Data_type  \
# 11     812                 92.0                401.0     1.0          2
# 14     815                105.0                415.0     1.0          2
# 30     831                 96.0                406.0     1.0          2
# 50     851                108.0                418.0     1.0          2
# 52     853                104.0                414.0     1.0          2
# 63     864                100.0                409.0     1.0          2
# 65     866                106.0                416.0     1.0          2
# 68     869                 95.0                405.0     5.0          2
# 88     889                104.0                414.0     5.0          2
# 90     891                109.0                419.0     5.0          4
# 91     892                108.0                417.0     5.0          3
# 93     894                106.0                416.0     5.0          2
# ...

# %%
cherry_blossoms.loc[cherry_blossoms['Full_flowering_date'] < 400, 'month'] = 'March'
cherry_blossoms.loc[(cherry_blossoms['Full_flowering_date'] > 400) & (cherry_blossoms['Full_flowering_date'] < 500),'month'] = 'April'
cherry_blossoms.loc[(cherry_blossoms['Full_flowering_date'] > 500) & (cherry_blossoms['Full_flowering_date'] < 600),'month'] = 'May'
#cherry_blossoms.loc[cherry_blossoms['Full_flowering_date'] > 500, 'month'] = 'May'

# %%
cherry_blossoms.head()
# Out:
#      AD  Full_flowering_year  Full_flowering_date  Source  Data_type  \
# 11  812                 92.0                401.0     1.0          2
# 14  815                105.0                415.0     1.0          2
# 30  831                 96.0                406.0     1.0          2
# 50  851                108.0                418.0     1.0          2
# 52  853                104.0                414.0     1.0          2
#
#             Reference_Name                          rolling_date  month
# 11              NIHON-KOKI  AxesSubplot(0.125,0.125;0.775x0.755)  April
# 14              NIHON-KOKI  AxesSubplot(0.125,0.125;0.775x0.755)  April
# 30              NIHON-KOKI  AxesSubplot(0.125,0.125;0.775x0.755)  April
# 50  MONTOKUTENNO-JITSUROKU  AxesSubplot(0.125,0.125;0.775x0.755)  April
# 52  MONTOKUTENNO-JITSUROKU  AxesSubplot(0.125,0.125;0.775x0.755)  April

# %% [markdown]
# ### 17. Using your new column, how many blossomings happened in each month?

# %%
cherry_blossoms.month.value_counts()
# Out:
# April    813
# March      9
# May        3
# Name: month, dtype: int64

# %% [markdown]
# ### 18. Graph how many blossomings happened in each month.

# %%
cherry_blossoms.month.value_counts().plot(kind='barh', x='count', y='month', color='red', title='Frequency of Cherry Blossoms Bloom Each Month', fontsize=14)

# %% [markdown]
# ## 19. Adding a day-of-month column
#
# Now we're going to add a new column called "day of month." It's actually a little tougher than it should be since the `Full-flowering date` column is a *float* instead of an integer.

# %%
cherry_blossoms.dtypes
# Out:
# AD                       int64
# Full_flowering_year    float64
# Full_flowering_date    float64
# Source                 float64
# Data_type                int64
# Reference_Name          object
# rolling_date            object
# month                   object
# dtype: object

# %% [markdown]
# And if you try to convert it to an int, **pandas yells at you!**

# %%
cherry_blossoms['Full_flowering_date'] = cherry_blossoms.Full_flowering_date.astype(int)
cherry_blossoms
# Out:
#         AD  Full_flowering_year  Full_flowering_date  Source  Data_type  \
# 11     812                 92.0                    1     1.0          2
# 14     815                105.0                   15     1.0          2
# 30     831                 96.0                    6     1.0          2
# 50     851                108.0                   18     1.0          2
# 52     853                104.0                   14     1.0          2
# 63     864                100.0                    9     1.0          2
# 65     866                106.0                   16     1.0          2
# 68     869                 95.0                    5     5.0          2
# 88     889                104.0                   14     5.0          2
# 90     891                109.0                   19     5.0          4
# 91     892                108.0                   17     5.0          3
# 93     894                106.0                   16     5.0          2
# ...

# %%
cherry_blossoms.dtypes #check the types of column Full_flowering_date. it is already changed into int64. It is successful because I already removed all the NaN values in the beginning.
# Out:
# AD                       int64
# Full_flowering_year    float64
# Full_flowering_date      int64
# Source                 float64
# Data_type                int64
# Reference_Name          object
# rolling_date            object
# month                   object
# dtype: object

# %% [markdown]
# That's because, as you can read, you can't have an `NaN` be an integer. But, for some reason, it *can* be a float. Ugh! So what we'll do is **drop all of the na values, then convert them to integers to get rid of the decimals.**
#
# I'll show you the first 5 here.

# %%
cherry_blossoms['Full_flowering_date'].dropna().astype(int).head()
# Out:
# 11     1
# 14    15
# 30     6
# 50    18
# 52    14
# Name: Full_flowering_date, dtype: int64

# %%
cherry_blossoms['Full_flowering_date']=cherry_blossoms.Full_flowering_date.astype(str)

# %% [markdown]
# On the next line, I take the first character of the row and add a bunch of exclamation points on it. I want you to edit this code to **return the last TWO digits of the number**. This only shows you the first 5, by the way.
#
# You might want to look up 'list slicing.'

# %%
#cherry_blossoms['Full-flowering date'].dropna().astype(int).astype(str).apply(lambda value: value[0] + "!!!").head()
#cherry_blossoms['Full_flowering_date'].str.slice(start=0)
cherry_blossoms['Full_flowering_date'] = cherry_blossoms['Full_flowering_date'].str[-2:]
cherry_blossoms
# Out:
#         AD  Full_flowering_year Full_flowering_date  Source  Data_type  \
# 11     812                 92.0                  01     1.0          2
# 14     815                105.0                  15     1.0          2
# 30     831                 96.0                  06     1.0          2
# 50     851                108.0                  18     1.0          2
# 52     853                104.0                  14     1.0          2
# 63     864                100.0                  09     1.0          2
# 65     866                106.0                  16     1.0          2
# 68     869                 95.0                  05     5.0          2
# 88     889                104.0                  14     5.0          2
# 90     891                109.0                  19     5.0          4
# 91     892                108.0                  17     5.0          3
# 93     894                106.0                  16     5.0          2
# ...

# %% [markdown]
# Now that you've successfully extracted the last two letters, save them into a new column called `'day-of-month'`

# %%
cherry_blossoms['Day_of_month'] = cherry_blossoms['Full_flowering_date'] 
cherry_blossoms.head(10)
# Out:
#      AD  Full_flowering_year Full_flowering_date  Source  Data_type  \
# 11  812                 92.0                   1     1.0          2
# 14  815                105.0                  15     1.0          2
# 30  831                 96.0                   6     1.0          2
# 50  851                108.0                  18     1.0          2
# 52  853                104.0                  14     1.0          2
# 63  864                100.0                   9     1.0          2
# 65  866                106.0                  16     1.0          2
# 68  869                 95.0                   5     5.0          2
# 88  889                104.0                  14     5.0          2
# 90  891                109.0                  19     5.0          4
#
#              Reference_Name                          rolling_date  month  \
# 11               NIHON-KOKI  AxesSubplot(0.125,0.125;0.775x0.755)  April
# ...

# %% [markdown]
# ### 20. Adding a date column
#
# Now take the `'month'` and `'day-of-month'` columns and combine them in order to create a new column called `'date'`

# %%
cherry_blossoms['Date'] = cherry_blossoms['month'].str.cat(cherry_blossoms['Day_of_month'], sep=' , ')
cherry_blossoms.Date
# Out:
# 11       April , 1
# 14      April , 15
# 30       April , 6
# 50      April , 18
# 52      April , 14
# 63       April , 9
# 65      April , 16
# 68       April , 5
# 88      April , 14
# 90      April , 19
# 91      April , 17
# 93      April , 16
# 94      April , 14
# 95      April , 13
# 101     April , 12
# 107      April , 7
# 111      April , 4
# 112     April , 20
# 116      April , 5
# 122     April , 14
# 125      April , 8
# 129      April , 7
# 132     April , 16
# 140     April , 19
# 148     April , 17
# 149      April , 5
# 154     March , 30
# 156     April , 22
# 157     April , 19
# 158      April , 7
#            ...
# 1185    April , 12
# 1186     April , 5
# 1187    April , 15
# 1188     April , 3
# 1189    March , 29
# 1190     April , 7
# 1191     April , 3
# 1192     April , 7
# 1193     April , 9
# 1194     April , 9
# 1195    April , 12
# 1196     April , 7
# 1197     April , 1
# 1198     April , 4
# 1199     April , 9
# 1200     April , 6
# ...

# %% [markdown]
# # YOU ARE DONE.
#
# And **incredible.**
