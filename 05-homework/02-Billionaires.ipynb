# %% [markdown]
# # Homework 5, Part 2: Answer questions with pandas
#
# **Use the Excel file to answer the following questions.** This is a little more typical of what your data exploration will look like with pandas.

# %% [markdown]
# ## 0) Setup
#
# Import pandas **with the correct name** and set `matplotlib` to always display graphics in the notebook.

# %%
# !pip install xlrd
import pandas as pd
import matplotlib

# %matplotlib inline

# %% [markdown]
# ## 1) Reading in an Excel file
#
# Use pandas to read in the `richpeople.xlsx` Excel file, saving it as a variable with the name we'll always use for a dataframe.
#
# > **TIP:** You will use `read_excel` instead of `read_csv`, *but you'll also need to install a new library*. You might need to restart your kernel afterward!

# %%
import pandas as pd
import xlrd
rich_people = pd.read_excel('richpeople.xlsx')
print(rich_people)

#import xlrd is needed because the file is in excel file not csv.
# Out:
#       year                          name  rank           citizenship  \
# 0     2014          A. Jerrold Perenchio   663         United States
# 1     2014            Abdulla Al Futtaim   687  United Arab Emirates
# 2     2014  Abdulla bin Ahmad Al Ghurair   305  United Arab Emirates
# 3     2014             Abdullah Al Rajhi   731          Saudi Arabia
# 4     2014              Abdulsamad Rabiu  1372               Nigeria
# 5     2014               Abigail Johnson    50         United States
# 6     2014       Abilio dos Santos Diniz   609                Brazil
# 7     2014                 Achmad Hamami  1092             Indonesia
# 8     2014                    Adi Godrej   446                 India
# 9     2014      Aerin Lauder Zinterhofer  1465         United States
# 10    2014                   Ahmet Calik  1465                Turkey
# 11    2014             Ahmet Nazif Zorlu  1372                Turkey
# 12    2014                  Ahsen Ozokur  1143                Turkey
# ...

# %%
rich_people.head()
# Out:
#    year                          name  rank           citizenship countrycode  \
# 0  2014          A. Jerrold Perenchio   663         United States         USA
# 1  2014            Abdulla Al Futtaim   687  United Arab Emirates         ARE
# 2  2014  Abdulla bin Ahmad Al Ghurair   305  United Arab Emirates         ARE
# 3  2014             Abdullah Al Rajhi   731          Saudi Arabia         SAU
# 4  2014              Abdulsamad Rabiu  1372               Nigeria         NGA
#
#    networthusbillion   selfmade         typeofwealth gender   age  ...  \
# 0                2.6  self-made            executive   male  83.0  ...
# 1                2.5  inherited            inherited   male   NaN  ...
# 2                4.8  inherited            inherited   male   NaN  ...
# 3                2.4  self-made    self-made finance   male   NaN  ...
# 4                1.2  self-made  founder non-finance   male  54.0  ...
#
#      relationshiptocompany foundingdate gdpcurrentus  \
# ...

# %% [markdown]
# ## 2) Checking your data
#
# Display the number of rows and columns in your data. Also display the names and data types of each column.

# %%
rich_people.shape
# Out:
# (1653, 30)

# %%
rich_people.dtypes
# Out:
# year                         int64
# name                        object
# rank                         int64
# citizenship                 object
# countrycode                 object
# networthusbillion          float64
# selfmade                    object
# typeofwealth                object
# gender                      object
# age                        float64
# industry                    object
# IndustryAggregates          object
# region                      object
# north                        int64
# politicalconnection        float64
# founder                      int64
# generationofinheritance     object
# sector                      object
# company                     object
# companytype                 object
# relationshiptocompany       object
# foundingdate               float64
# gdpcurrentus               float64
# sourceofwealth              object
# notes                       object
# notes2                      object
# source                      object
# ...

# %% [markdown]
# ## 3) Who are the top 10 richest billionaires? Use the `networthusbillion` column.

# %%
rich_people[['name', 'networthusbillion']].sort_values(by='networthusbillion', ascending=False).head(10)
# Out:
#                   name  networthusbillion
# 184         Bill Gates               76.0
# 226   Carlos Slim Helu               72.0
# 79      Amancio Ortega               64.0
# 1562    Warren Buffett               58.2
# 862      Larry Ellison               48.0
# 339         David Koch               40.0
# 247       Charles Koch               40.0
# 1364   Sheldon Adelson               38.0
# 280     Christy Walton               36.7
# 724         Jim Walton               34.7

# %% [markdown]
# #do the filter or select columns first and do the next command of sorting values etc

# %% [markdown]
# ## 4) How many male billionaires are there compared to the number of female billionares? What percent is that? Do they have a different average wealth?
#
# > **TIP:** The last part uses `groupby`, but the count/percent part does not.
# > **TIP:** When I say "average," you can pick what kind of average you use.

# %%
sorted_rich_people = rich_people[['name', 'gender']]
sorted_rich_people
# Out:
#                               name  gender
# 0             A. Jerrold Perenchio    male
# 1               Abdulla Al Futtaim    male
# 2     Abdulla bin Ahmad Al Ghurair    male
# 3                Abdullah Al Rajhi    male
# 4                 Abdulsamad Rabiu    male
# 5                  Abigail Johnson  female
# 6          Abilio dos Santos Diniz    male
# 7                    Achmad Hamami    male
# 8                       Adi Godrej    male
# 9         Aerin Lauder Zinterhofer  female
# 10                     Ahmet Calik    male
# 11               Ahmet Nazif Zorlu    male
# 12                    Ahsen Ozokur  female
# 13                  Airat Shaimiev    male
# 14                      Ajay Kalsi    male
# 15                    Ajay Piramal    male
# 16                     Akio Nitori    male
# 17                      Akira Mori    male
# 18                  Alain Bouchard    male
# 19                   Alain Merieux    male
# 20                 Alain Taravella    male
# ...

# %%
count_sorted_richpeople = sorted_rich_people.gender.value_counts()
csp = count_sorted_richpeople
csp
# Out:
# male      1473
# female     180
# Name: gender, dtype: int64

# %%
type(csp)
# Out:
# pandas.core.series.Series

# %%
pct = csp/csp.sum()*100
pct

#for series you cannot use.column. do the calculations straightly!
# Out:
# male      89.110708
# female    10.889292
# Name: gender, dtype: float64

# %% [markdown]
# ## 5) What is the most common source/type of wealth? Is it different between males and females?
#
# > **TIP:** You know how to `groupby` and you know how to count how many times a value is in a column. Can you put them together???
# > **TIP:** Use percentages for this, it makes it a lot more readable.

# %%
source_wealth = rich_people[['name', 'gender','typeofwealth']]
source_wealth
# Out:
#                               name  gender              typeofwealth
# 0             A. Jerrold Perenchio    male                 executive
# 1               Abdulla Al Futtaim    male                 inherited
# 2     Abdulla bin Ahmad Al Ghurair    male                 inherited
# 3                Abdullah Al Rajhi    male         self-made finance
# 4                 Abdulsamad Rabiu    male       founder non-finance
# 5                  Abigail Johnson  female                 inherited
# 6          Abilio dos Santos Diniz    male                 inherited
# 7                    Achmad Hamami    male       founder non-finance
# 8                       Adi Godrej    male                 inherited
# 9         Aerin Lauder Zinterhofer  female                 inherited
# 10                     Ahmet Calik    male  privatized and resources
# 11               Ahmet Nazif Zorlu    male         self-made finance
# 12                    Ahsen Ozokur  female                 inherited
# ...

# %%
type(source_wealth)
# Out:
# pandas.core.frame.DataFrame

# %%
source_wealth.groupby(by=['gender']).typeofwealth.value_counts(normalize=True)
# Out:
# gender  typeofwealth
# female  inherited                   0.788889
#         founder non-finance         0.116667
#         executive                   0.033333
#         self-made finance           0.033333
#         privatized and resources    0.027778
# male    founder non-finance         0.303195
#         inherited                   0.247451
#         self-made finance           0.229776
#         privatized and resources    0.127124
#         executive                   0.092454
# Name: typeofwealth, dtype: float64

# %% [markdown]
# ## 6) What companies have the most billionaires? Graph the top 5 as a horizontal bar graph.
#
# > **TIP:** First find the answer to the question, then just try to throw `.plot()` on the end
# >
# > **TIP:** You can use `.head()` on *anything*, not just your basic `df`
# >
# > **TIP:** You might feel like you should use `groupby`, but don't! There's an easier way to count.
# >
# > **TIP:** Make the largest bar be at the top of the graph
# >
# > **TIP:** If your chart seems... weird, think about where in the process you're sorting vs using `head`

# %%
top5companies = rich_people[['name','company']].sort_values(by='company', ascending=True).head(5)
top5companies
#rich_people[['name', 'networthusbillion']].sort_values(by='networthusbillion', ascending=False).head(10)
# Out:
#                       name                     company
# 1004       Mark Zuckerberg                    Facebook
# 931       Liselott Persson                         H&M
# 1395        Stefan Persson                         H&M
# 896   Leonardo Del Vecchio                  ?Luxottica
# 563        Hans Peter Wild  ?Rudolf WILD GmbH & Co. KG

# %%
rich_people.company.value_counts().head(5).sort_values(ascending=False)
# Out:
# Hyatt                  11
# Oetker-Gruppe           8
# S. C. Johnson & Son     7
# Walmart                 6
# Cargill                 6
# Name: company, dtype: int64

# %%
rich_people.company.value_counts().head(5).sort_values(ascending=False).plot( title='Companies with the Most Billionaires', kind='barh')

# %% [markdown]
# ## 7) How much money do these billionaires have in total?

# %%
rich_people.networthusbillion.sum()
# Out:
# 6454.400000000001

# %% [markdown]
# ## 8) What are the top 10 countries with the most money held by billionaires?
#
# I am **not** asking which country has the most billionaires - this is **total amount of money per country.**
#
# > **TIP:** Think about it in steps - "I want them organized by country," "I want their net worth," "I want to add it all up," and "I want 10 of them." Just chain it all together.

# %%
rich_people.groupby(by='countrycode').networthusbillion.sum(ascending=False).head(10).sort_values(ascending=False)
# Out:
# countrycode
# BRA    192.2
# CAN    112.8
# AUS     85.4
# CHE     80.2
# CHL     41.3
# AUT     33.8
# ARE     14.6
# ARG     11.3
# BEL      8.0
# AGO      3.7
# Name: networthusbillion, dtype: float64

# %% [markdown]
# ## 9) How old is an average billionaire? How old are self-made billionaires  vs. non self-made billionaires?

# %%
sorted_b=rich_people[['name','selfmade','age']]
sorted_b
# Out:
#                               name   selfmade   age
# 0             A. Jerrold Perenchio  self-made  83.0
# 1               Abdulla Al Futtaim  inherited   NaN
# 2     Abdulla bin Ahmad Al Ghurair  inherited   NaN
# 3                Abdullah Al Rajhi  self-made   NaN
# 4                 Abdulsamad Rabiu  self-made  54.0
# 5                  Abigail Johnson  inherited  52.0
# 6          Abilio dos Santos Diniz  inherited  77.0
# 7                    Achmad Hamami  self-made  83.0
# 8                       Adi Godrej  inherited  71.0
# 9         Aerin Lauder Zinterhofer  inherited  44.0
# 10                     Ahmet Calik  self-made  56.0
# 11               Ahmet Nazif Zorlu  self-made  69.0
# 12                    Ahsen Ozokur  inherited  63.0
# 13                  Airat Shaimiev  self-made  51.0
# 14                      Ajay Kalsi  self-made  53.0
# 15                    Ajay Piramal  self-made  58.0
# 16                     Akio Nitori  self-made  70.0
# ...

# %%
sorted_b=rich_people[['name','selfmade','age']]
average_b = sorted_b.age.mean()
average_b
#average age for billionaire
# Out:
# 63.34213836477988

# %%
selfmade_b = sorted_b[sorted_b.selfmade == 'self-made'].age.mean()
selfmade_b
# Out:
# 62.62589928057554

# %%
nonselfmade_b = sorted_b[sorted_b.selfmade == 'inherited'].age.mean()
nonselfmade_b
# Out:
# 64.96218487394958

# %% [markdown]
# ## 10) Who are the youngest billionaires? Who are the oldest? Make a graph of the distribution of ages.
#
# > **TIP:** You use `.plot()` to graph values in a column independently, but `.hist()` to draw a [histogram](https://www.mathsisfun.com/data/histograms.html) of the distribution of their values

# %%
oldest_b= rich_people[['name', 'age']].sort_values(by='age', ascending=False).head(10)
oldest_b
# Out:
#                           name   age
# 343     David Rockefeller, Sr.  98.0
# 816              Karl Wlaschek  96.0
# 836             Kirk Kerkorian  96.0
# 588              Henry Hillman  95.0
# 435         Erika Pohl-Stroher  95.0
# 1428         Sulaiman Al Rajhi  94.0
# 122          Anne Cox Chambers  94.0
# 815              Karl Albrecht  94.0
# 77    Aloysio de Andrade Faria  93.0
# 1560            Wang Yung-Tsai  93.0

# %%
rich_people[['name', 'age']].sort_values(by='age', ascending=False).head(10).plot(title ='The Oldest Billionaires in the World', kind='bar')

# %%
rich_people[['name', 'age']].sort_values(by='age', ascending=False).head(10).plot(title ='The Oldest Billionaires in the World', kind='hist')

# %%
rich_people[['name', 'age']].sort_values(by='age', ascending=True).head(10)
# Out:
#                             name   age
# 1172                 Perenna Kei  24.0
# 397             Dustin Moskovitz  29.0
# 1004             Mark Zuckerberg  29.0
# 127          Anton Kathrein, Jr.  29.0
# 394                 Drew Houston  30.0
# 28    Albert von Thurn und Taxis  30.0
# 406              Eduardo Saverin  31.0
# 1340                Scott Duncan  31.0
# 1607                 Yang Huiyan  32.0
# 991      Marie Besnier Beauvalot  33.0

# %%
sorted_rp=rich_people[['name', 'age']].sort_values(by='age', ascending=True).head(10)
sorted_rp.plot(x='name', y='age', title ='Youngest Billionaires in the World', kind ='bar')

# %%
sorted_rp=rich_people[['name', 'age']].sort_values(by='age', ascending=True).head(10)
sorted_rp.plot(x='name', y='age', title ='Youngest Billionaires in the World', kind ='hist')

# %% [markdown]
# ## 11) Make a scatterplot of net worth compared to age

# %%
rich_people.plot(x='networthusbillion', y='age', kind='scatter')

# %% [markdown]
# ## 13) Make a bar graph of the wealth of the top 10 richest billionaires
#
# > **TIP:** When you make your plot, you'll need to set the `x` and `y` or else your chart will look _crazy_
# >
# > **TIP:** x and y might be the opposite of what you expect them to be

# %%
Top10_b = rich_people[['name','networthusbillion']].sort_values(by='networthusbillion', ascending=False).head(10)
Top10_b
# Out:
#                   name  networthusbillion
# 184         Bill Gates               76.0
# 226   Carlos Slim Helu               72.0
# 79      Amancio Ortega               64.0
# 1562    Warren Buffett               58.2
# 862      Larry Ellison               48.0
# 339         David Koch               40.0
# 247       Charles Koch               40.0
# 1364   Sheldon Adelson               38.0
# 280     Christy Walton               36.7
# 724         Jim Walton               34.7

# %%
Top10_b.plot(x='name', y='networthusbillion', title='Top 10 Richest Billionaires', kind ='barh')
