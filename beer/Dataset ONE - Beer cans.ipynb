# %% [markdown]
# # Homework 6, Part One: Lots and lots of questions about beer

# %% [markdown]
# ### Do your importing and your setup

# %%
import pandas as pd

# %matplotlib inline

# %% [markdown]
# ## Read in the file `craftcans.csv`, and look at the first first rows

# %%
df = pd.read_csv('craftcans.csv', na_values=[0,"Does not apply","NaN"])
df
# Out:
#                                        Beer                        Brewery  \
# 0                              Get Together              NorthGate Brewing
# 1                             Maggie's Leap              NorthGate Brewing
# 2                                Wall's End              NorthGate Brewing
# 3                                   Pumpion              NorthGate Brewing
# 4                                Stronghold              NorthGate Brewing
# 5                               Parapet ESB              NorthGate Brewing
# 6                            Citra Ass Down      Against the Grain Brewery
# 7                            London Balling      Against the Grain Brewery
# 8                                      35 K      Against the Grain Brewery
# 9                                    A Beer      Against the Grain Brewery
# 10                          Rules are Rules      Against the Grain Brewery
# ...

# %% [markdown]
# ## How many rows do you have in the data? What are the column types?

# %%
df.shape
# Out:
# (2416, 7)

# %%
df.dtypes
# Out:
# Beer         object
# Brewery      object
# Location     object
# Style        object
# Size         object
# ABV          object
# IBUs        float64
# dtype: object

# %% [markdown]
# # Checking out our alcohol

# %% [markdown]
# ## What are the top 10 producers of cans of beer?

# %%
df.Brewery.value_counts(ascending=False).head(10)
# Out:
# Brewery Vivant                62
# Oskar Blues Brewery           46
# Sun King Brewing Company      38
# Cigar City Brewing Company    25
# Sixpoint Craft Ales           24
# Hopworks Urban Brewery        23
# Stevens Point Brewery         22
# Great Crescent Brewery        20
# 21st Amendment Brewery        20
# SanTan Brewing Company        19
# Name: Brewery, dtype: int64

# %% [markdown]
# ## What is the most common ABV? (alcohol by volume)

# %%
df.ABV.value_counts(ascending=False)
# Out:
# 5.00%     215
# 5.50%     158
# 6.00%     125
# 6.50%     123
# 5.20%     107
# 7.00%      92
# 4.50%      89
# 4.80%      72
# 5.60%      66
# 5.80%      66
# 5.10%      62
# 5.30%      60
# 6.20%      59
# 4.90%      59
# 8.00%      57
# 4.70%      57
# 5.70%      52
# 6.80%      52
# 5.40%      50
# 7.50%      43
# 4.20%      38
# 6.30%      38
# 4.00%      38
# 7.20%      37
# 9.90%      35
# 5.90%      34
# 6.90%      32
# 4.60%      32
# 8.50%      26
# 6.70%      25
#          ...
# 9.50%       9
# 4.10%       9
# 7.40%       8
# 8.30%       8
# 7.90%       7
# 3.80%       6
# 8.80%       6
# 3.50%       6
# 9.60%       5
# 7.60%       5
# 9.30%       5
# 9.70%       5
# 3.70%       4
# 8.10%       4
# 8.60%       4
# 9.80%       3
# 8.40%       3
# 9.10%       3
# 3.20%       3
# 2.70%       2
# 8.90%       2
# 9.40%       1
# 12.50%      1
# 10.40%      1
# 3.40%       1
# 0.10%       1
# 12.00%      1
# 10.00%      1
# 2.80%       1
# 12.80%      1
# ...

# %% [markdown]
# ## Oh, weird, ABV isn't a number. Convert it to a number for me, please.
#
# It's going to take a few steps!
#
# ### First, let's just look at the ABV column by itself

# %%
df.ABV
# Out:
# 0        4.50%
# 1        4.90%
# 2        4.80%
# 3        6.00%
# 4        6.00%
# 5        5.60%
# 6        8.00%
# 7       12.50%
# 8        7.70%
# 9        4.20%
# 10       5.00%
# 11       6.60%
# 12       4.00%
# 13       5.50%
# 14       7.60%
# 15       5.10%
# 16       6.50%
# 17       6.00%
# 18       5.00%
# 19       5.20%
# 20       4.80%
# 21       7.20%
# 22       6.70%
# 23       4.90%
# 24       8.00%
# 25       7.50%
# 26       6.00%
# 27       8.00%
# 28       6.30%
# 29       5.80%
#          ...
# 2386     5.70%
# 2387     6.20%
# 2388     4.90%
# 2389     9.90%
# 2390     6.20%
# 2391     5.80%
# 2392     5.20%
# 2393     8.50%
# 2394     7.00%
# 2395     5.30%
# 2396     5.60%
# 2397     4.90%
# 2398     5.10%
# 2399     4.00%
# 2400     5.50%
# 2401     5.10%
# 2402     5.10%
# 2403     9.70%
# 2404     5.10%
# 2405     6.70%
# 2406     6.20%
# 2407     8.30%
# 2408     7.00%
# 2409     4.90%
# 2410     9.90%
# 2411     5.30%
# 2412     9.90%
# ...

# %% [markdown]
# ### Hm, `%` isn't part of  a number. Let's remove it.
#
# When you're confident you got it right, save the results back into the `ABV` column.
#
# - *Tip: In programming the easiest way to remove something is to *replacing it with nothing*.
# - *Tip: "nothing" might seem like `NaN` sinc we talked about it a lot in class, but in this case it isn't! It's just an empty string, like ""*
# - *Tip: `.replace` is used for replacing ENTIRE cells, while `.str.replace` is useful for replacing PARTS of cells (see my New York example)*

# %%
df['ABV'] = df.ABV.str.replace('%','')
df
# Out:
#                                        Beer                        Brewery  \
# 0                              Get Together              NorthGate Brewing
# 1                             Maggie's Leap              NorthGate Brewing
# 2                                Wall's End              NorthGate Brewing
# 3                                   Pumpion              NorthGate Brewing
# 4                                Stronghold              NorthGate Brewing
# 5                               Parapet ESB              NorthGate Brewing
# 6                            Citra Ass Down      Against the Grain Brewery
# 7                            London Balling      Against the Grain Brewery
# 8                                      35 K      Against the Grain Brewery
# 9                                    A Beer      Against the Grain Brewery
# 10                          Rules are Rules      Against the Grain Brewery
# ...

# %% [markdown]
# ### Now let's turn `ABV` into a numeric data type
#
# Save the results back into the `ABV` column (again), and then check `df.dtypes` to make sure it worked.
#
# - *Tip: We used `.astype(int)` during class, but this has a decimal in it...*

# %%
df['ABV'] = df.ABV.astype(float)
df
# Out:
#                                        Beer                        Brewery  \
# 0                              Get Together              NorthGate Brewing
# 1                             Maggie's Leap              NorthGate Brewing
# 2                                Wall's End              NorthGate Brewing
# 3                                   Pumpion              NorthGate Brewing
# 4                                Stronghold              NorthGate Brewing
# 5                               Parapet ESB              NorthGate Brewing
# 6                            Citra Ass Down      Against the Grain Brewery
# 7                            London Balling      Against the Grain Brewery
# 8                                      35 K      Against the Grain Brewery
# 9                                    A Beer      Against the Grain Brewery
# 10                          Rules are Rules      Against the Grain Brewery
# ...

# %%
df.dtypes
# Out:
# Beer         object
# Brewery      object
# Location     object
# Style        object
# Size         object
# ABV         float64
# IBUs        float64
# dtype: object

# %% [markdown]
# ## What's the ABV of the average beer look like?
#
# ### Show me in two different ways: one command to show the `median`/`mean`/etc, and secondly show me a chart

# %%
df.ABV.astype(float).mean()
# Out:
# 5.977342419080068

# %%
df.ABV.describe()
# Out:
# count    2348.000000
# mean        5.977342
# std         1.354173
# min         0.100000
# 25%         5.000000
# 50%         5.600000
# 75%         6.700000
# max        12.800000
# Name: ABV, dtype: float64

# %%
df.ABV.hist(alpha=0.4, color='g')

# %% [markdown]
# ### We don't have ABV for all of the beers, how many are we missing them from?
#
# - *Tip: You can use `isnull()` or `notnull()` to see where a column is missing data.*
# - *Tip: You just want to count how many `True`s and `False`s there are.*
# - *Tip: It's a weird trick involving something we usually use to count things in a column*

# %%
df.ABV.value_counts().tail()
# Out:
# 0.1     1
# 12.0    1
# 2.8     1
# 9.4     1
# 12.8    1
# Name: ABV, dtype: int64

# %%
df.ABV.isna().value_counts()
# Out:
# False    2348
# True       68
# Name: ABV, dtype: int64

# %% [markdown]
# # Looking at location
#
# Brooklyn used to produce 80% of the country's beer! Let's see if it's still true.

# %% [markdown]
# ## What are the top 10 cities in the US for canned craft beer?

# %%
df.dtypes
# Out:
# Beer         object
# Brewery      object
# Location     object
# Style        object
# Size         object
# ABV         float64
# IBUs        float64
# dtype: object

# %%
df.Location.value_counts(ascending=False).head(10)
# Out:
# Grand Rapids, MI    66
# Chicago, IL         55
# Portland, OR        52
# Indianapolis, IN    43
# San Diego, CA       42
# Boulder, CO         41
# Denver, CO          40
# Brooklyn, NY        38
# Seattle, WA         35
# Longmont, CO        33
# Name: Location, dtype: int64

# %% [markdown]
# ## List all of the beer from Brooklyn, NY

# %%
df[df.Location =='Brooklyn, NY']
# Out:
#                                  Beer              Brewery      Location  \
# 115                            4Beans  Sixpoint Craft Ales  Brooklyn, NY
# 210                            Jammer  Sixpoint Craft Ales  Brooklyn, NY
# 246                           Abigale  Sixpoint Craft Ales  Brooklyn, NY
# 404                     Nomader Weiss    Evil Twin Brewing  Brooklyn, NY
# 421                               Rad  Sixpoint Craft Ales  Brooklyn, NY
# 439                      Molotov Lite    Evil Twin Brewing  Brooklyn, NY
# 588                           Bengali  Sixpoint Craft Ales  Brooklyn, NY
# 713                     Sensi Harvest  Sixpoint Craft Ales  Brooklyn, NY
# 969                            Hi-Res  Sixpoint Craft Ales  Brooklyn, NY
# 987             KelSo Nut Brown Lager   KelSo Beer Company  Brooklyn, NY
# 1057                    Global Warmer  Sixpoint Craft Ales  Brooklyn, NY
# 1074               Autumnation (2013)  Sixpoint Craft Ales  Brooklyn, NY
# ...

# %% [markdown]
# ## What brewery in Brooklyn puts out the most cans of beer?

# %%
Brooklyn_beer= df[df.Location =='Brooklyn, NY']

Brooklyn_beer.Brewery.value_counts(ascending=False)
# Out:
# Sixpoint Craft Ales    24
# Brooklyn Brewery        6
# Evil Twin Brewing       5
# KelSo Beer Company      3
# Name: Brewery, dtype: int64

# %% [markdown]
# ## What are the five most popular styles of beer produced by Sixpoint?

# %%
Sixpoint = Brooklyn_beer[Brooklyn_beer.Brewery == 'Sixpoint Craft Ales']
Sixpoint
# Out:
#                               Beer              Brewery      Location  \
# 115                         4Beans  Sixpoint Craft Ales  Brooklyn, NY
# 210                         Jammer  Sixpoint Craft Ales  Brooklyn, NY
# 246                        Abigale  Sixpoint Craft Ales  Brooklyn, NY
# 421                            Rad  Sixpoint Craft Ales  Brooklyn, NY
# 588                        Bengali  Sixpoint Craft Ales  Brooklyn, NY
# 713                  Sensi Harvest  Sixpoint Craft Ales  Brooklyn, NY
# 969                         Hi-Res  Sixpoint Craft Ales  Brooklyn, NY
# 1057                 Global Warmer  Sixpoint Craft Ales  Brooklyn, NY
# 1074            Autumnation (2013)  Sixpoint Craft Ales  Brooklyn, NY
# 1267                     The Crisp  Sixpoint Craft Ales  Brooklyn, NY
# 1268                  Sweet Action  Sixpoint Craft Ales  Brooklyn, NY
# 1269                 Righteous Ale  Sixpoint Craft Ales  Brooklyn, NY
# ...

# %%
Sixpoint.Style.value_counts(ascending=False).head(5)
# Out:
# American IPA       4
# German Pilsener    2
# Cream Ale          2
# Baltic Porter      2
# Rye Beer           2
# Name: Style, dtype: int64

# %% [markdown]
# ## List all of the breweries in New York state.
#
# - *Tip: We want to match *part* of the `Location` column, but not all of it.*
# - *Tip: Watch out for `NaN` values! You might be close, but you'll need to pass an extra parameter to make it work without an error.*

# %%
df.dtypes

# %%
df.Location
# Out:
# 0           Minneapolis, MN
# 1           Minneapolis, MN
# 2           Minneapolis, MN
# 3           Minneapolis, MN
# 4           Minneapolis, MN
# 5           Minneapolis, MN
# 6            Louisville, KY
# 7            Louisville, KY
# 8            Louisville, KY
# 9            Louisville, KY
# 10           Louisville, KY
# 11           Louisville, KY
# 12           Louisville, KY
# 13           Louisville, KY
# 14           Louisville, KY
# 15           Louisville, KY
# 16           Louisville, KY
# 17           Louisville, KY
# 18           Louisville, KY
# 19           Framingham, MA
# 20           Framingham, MA
# 21           Framingham, MA
# 22           Framingham, MA
# 23           Framingham, MA
# 24            San Diego, CA
# 25            San Diego, CA
# 26            San Diego, CA
# 27            San Diego, CA
# 28            San Diego, CA
# 29            San Diego, CA
#                ...
# 2386            Lahaina, HI
# 2387            Lahaina, HI
# ...

# %% [markdown]
# ### Now *count* all of the breweries in New York state

# %%
df[df['Location'].str.contains("NY", na=False)].Brewery.value_counts().sort_values(ascending=False)
# Out:
# Sixpoint Craft Ales              24
# Matt Brewing Company             13
# Brooklyn Brewery                  6
# Evil Twin Brewing                 5
# Blue Point Brewing Company        4
# Butternuts Beer and Ale           4
# KelSo Beer Company                3
# The Bronx Brewery                 3
# Bomb Beer Company                 2
# Chatham Brewing                   2
# Upstate Brewing Company           2
# Montauk Brewing Company           2
# Dundee Brewing Company            1
# The Manhattan Brewing Company     1
# Newburgh Brewing Company          1
# Southampton Publick House         1
# Name: Brewery, dtype: int64

# %% [markdown]
# # Measuring International Bitterness Units
#
# ## Display all of the IPAs
#
# Include American IPAs, Imperial IPAs, and anything else with "IPA in it."
#
# IPA stands for [India Pale Ale](https://www.bonappetit.com/story/ipa-beer-styles), and is probably the most popular kind of beer in the US for people who are drinking [craft beer](https://www.craftbeer.com/beer/what-is-craft-beer).

# %%
df.dtypes
# Out:
# Beer         object
# Brewery      object
# Location     object
# Style        object
# Size         object
# ABV         float64
# IBUs        float64
# dtype: object

# %%
df[df['Beer'].str.contains("IPA", na=False)].Beer.value_counts().sort_values(ascending=False)
# Out:
# Dagger Falls IPA                                   3
# Green Monsta IPA                                   2
# Deviant Dale's IPA                                 2
# TailGate IPA                                       2
# Our Legacy IPA                                     2
# Point the Way IPA                                  2
# Long Hammer IPA                                    2
# Bitter Biker Double IPA                            2
# Tsunami IPA                                        2
# Hop Slayer Double IPA (2011)                       2
# Ranger IPA                                         2
# Gandhi-Bot Double IPA                              2
# CAPT Black IPA                                     2
# Lumberyard IPA                                     1
# Caldera IPA (2009)                                 1
# Hop Stalker Fresh Hop IPA                          1
# Point the Way IPA (2012)                           1
# Caldera IPA                                        1
# ...

# %% [markdown]
# IPAs are usually pretty hoppy and bitter. IBU stands for [International Bitterness Unit](http://www.thebrewenthusiast.com/ibus/), and while a lot of places like to brag about having the most bitter beer (it's an American thing!), IBUs don't necessary *mean anything*.
#
# Let's look at how different beers have different IBU measurements.

# %% [markdown]
# ## Try to get the average IBU measurement across all beers

# %%
df.dtypes
# Out:
# Beer         object
# Brewery      object
# Location     object
# Style        object
# Size         object
# ABV         float64
# IBUs        float64
# dtype: object

# %%
df.IBUs.mean()
# Out:
# 42.71316725978647

# %% [markdown]
# ### Oh no, it doesn't work!
#
# It looks like some of those values *aren't numbers*. There are two ways to fix this:
#
# 1. Do the `.replace` and `np.nan` thing we did in class. Then convert the column to a number. This is boring.
# 2. When you're reading in your csv, there [is an option called `na_values`](http://pandas.pydata.org/pandas-docs/version/0.23/generated/pandas.read_csv.html). You can give it a list of **numbers or strings to count as `NaN`**. It's a lot easier than doing the `np.nan` thing, although you'll need to go add it up top and run all of your cells again.
#
# - *Tip: Make sure you're giving `na_values` a LIST, not just a string*
#
# ### Now try to get the average IBUs again

# %%
df.IBUs.mean()
# Out:
# 42.71316725978647

# %% [markdown]
# ## Draw the distribution of IBU measurements, but with *twenty* bins instead of the default of 10
#
# - *Tip: Every time I ask for a distribution, I'm looking for a histogram*
# - *Tip: Use the `?` to get all of the options for building a histogram*
# - *Tip: Make sure your `matplotlib` thing is set up right!*

# %%
df.IBUs.hist(bins=20, alpha=0.5, color='c')

# %%
df.IBUs
# Out:
# 0        50.0
# 1        26.0
# 2        19.0
# 3        38.0
# 4        25.0
# 5        47.0
# 6        68.0
# 7        80.0
# 8        25.0
# 9        42.0
# 10       25.0
# 11       21.0
# 12       13.0
# 13       17.0
# 14       68.0
# 15       38.0
# 16        NaN
# 17       65.0
# 18       20.0
# 19       18.0
# 20       15.0
# 21       80.0
# 22       65.0
# 23       45.0
# 24      100.0
# 25       85.0
# 26       24.0
# 27      100.0
# 28       30.0
# 29       28.0
#         ...
# 2386     30.0
# 2387     65.0
# 2388      NaN
# 2389      NaN
# 2390     42.0
# 2391     35.0
# 2392     40.0
# 2393      NaN
# 2394    113.0
# 2395     21.0
# 2396     11.0
# 2397     44.0
# 2398     40.0
# 2399     37.0
# 2400     34.0
# 2401     45.0
# 2402     45.0
# 2403    120.0
# 2404     20.0
# 2405     33.0
# 2406     99.0
# 2407     35.0
# 2408     65.0
# 2409     17.0
# 2410     98.0
# 2411     35.0
# 2412    100.0
# 2413     35.0
# 2414     85.0
# 2415     65.0
# ...

# %% [markdown]
# ## Hm, Interesting distribution. List all of the beers with IBUs above the 75th percentile
#
# - *Tip: There's a single that gives you the 25/50/75th percentile*
# - *Tip: You can just manually type the number when you list those beers*

# %%
df[df.IBUs>75]
# Out:
#                                  Beer                             Brewery  \
# 7                      London Balling           Against the Grain Brewery
# 21                         Excess IPL            Jack's Abby Craft Lagers
# 24                     Habitus (2014)           Mike Hess Brewing Company
# 25                              Solis           Mike Hess Brewing Company
# 27                            Habitus           Mike Hess Brewing Company
# 68                               Csar             Tin Man Brewing Company
# 79                         The Gadget                Four Fathers Brewing
# 89                         Gone A-Rye                 Cedar Creek Brewery
# 93                      Heavy Lifting           Boulevard Brewing Company
# 110                           Jah Mon          Rivertowne Brewing Company
# 170                      Bimini Twist                 3 Daughters Brewing
# 182                    Double Duckpin                 Union Craft Brewing
# ...

# %%
sorted_IBUs = df[df.IBUs>75]
sorted_75=sorted_IBUs.IBUs.sort_values(ascending=False)
sorted_75
# Out:
# 1662    138.0
# 989     135.0
# 611     130.0
# 249     126.0
# 1537    120.0
# 2403    120.0
# 2182    120.0
# 556     118.0
# 1783    115.0
# 186     115.0
# 1209    115.0
# 218     115.0
# 1168    115.0
# 2394    113.0
# 969     111.0
# 938     110.0
# 1633    110.0
# 1627    110.0
# 861     108.0
# 1724    105.0
# 1055    104.0
# 905     104.0
# 1972    103.0
# 2234    103.0
# 288     103.0
# 1104    101.0
# 1755    100.0
# 1216    100.0
# 1757    100.0
# 1872    100.0
#         ...
# 582      81.0
# 1882     80.0
# 2045     80.0
# 93       80.0
# 2186     80.0
# 2257     80.0
# 21       80.0
# 1001     80.0
# 1778     80.0
# 746      80.0
# 1044     80.0
# 1089     80.0
# 921      80.0
# 1157     80.0
# 855      80.0
# 790      80.0
# 459      80.0
# 7        80.0
# 735      80.0
# 1325     80.0
# 1363     80.0
# 590      80.0
# 1088     78.0
# 2055     77.0
# 1237     77.0
# 511      77.0
# 1019     77.0
# 782      77.0
# 652      76.0
# 1397     76.0
# ...

# %% [markdown]
# ## List all of the beers with IBUs below the 25th percentile

# %%
df[df.IBUs<25]
# Out:
#                                         Beer                          Brewery  \
# 2                                 Wall's End                NorthGate Brewing
# 11                             Flesh Gourd'n        Against the Grain Brewery
# 12                                  Sho'nuff        Against the Grain Brewery
# 13                               Bloody Show        Against the Grain Brewery
# 18                            The Brown Note        Against the Grain Brewery
# 19                               House Lager         Jack's Abby Craft Lagers
# 20                              Leisure Time         Jack's Abby Craft Lagers
# 26                                  Jucundus        Mike Hess Brewing Company
# 30                                      Park          Fort Point Beer Company
# 31                                 Westfalia          Fort Point Beer Company
# 32                                       KSA          Fort Point Beer Company
# ...

# %%
sorted_IBUs = df[df.IBUs<25]
sorted_25=sorted_IBUs.IBUs.sort_values(ascending=False)
sorted_25
# Out:
# 2161    24.0
# 2269    24.0
# 126     24.0
# 1169    24.0
# 1048    24.0
# 521     24.0
# 1861    24.0
# 2304    24.0
# 1873    24.0
# 1907    24.0
# 1911    24.0
# 1719    24.0
# 1915    24.0
# 26      24.0
# 2006    24.0
# 1594    24.0
# 996     24.0
# 1555    24.0
# 1380    24.0
# 2381    24.0
# 829     24.0
# 1392    24.0
# 1820    24.0
# 1996    23.0
# 1924    23.0
# 2036    23.0
# 2061    23.0
# 2127    23.0
# 519     23.0
# 1288    23.0
#         ...
# 322      9.0
# 1139     9.0
# 1080     9.0
# 658      8.0
# 159      8.0
# 454      8.0
# 838      8.0
# 778      8.0
# 105      8.0
# 2018     8.0
# 2053     8.0
# 453      8.0
# 1505     7.0
# 1801     7.0
# 2298     7.0
# 1842     7.0
# 1426     7.0
# 421      7.0
# 2289     7.0
# 1240     6.0
# 2064     6.0
# 313      6.0
# 1903     5.0
# 1340     5.0
# 169      5.0
# 318      5.0
# 1061     5.0
# 1860     4.0
# 1303     4.0
# 2339     4.0
# Name: IBUs, Length: 444, dtype: float64

# %% [markdown]
# ## List the median IBUs of each type of beer. Graph it.
#
# Put the highest at the top, and the missing ones at the bottom.
#
# - Tip: Look at the options for `sort_values` to figure out the `NaN` thing. The `?` probably won't help you here.

# %%
df.IBUs.sort_values(na_position='last')
# Out:
# 2339    4.0
# 1860    4.0
# 1303    4.0
# 1340    5.0
# 169     5.0
# 1061    5.0
# 1903    5.0
# 318     5.0
# 2064    6.0
# 313     6.0
# 1240    6.0
# 421     7.0
# 2298    7.0
# 1505    7.0
# 1842    7.0
# 1801    7.0
# 2289    7.0
# 1426    7.0
# 454     8.0
# 159     8.0
# 453     8.0
# 105     8.0
# 2018    8.0
# 838     8.0
# 778     8.0
# 658     8.0
# 2053    8.0
# 458     9.0
# 2292    9.0
# 564     9.0
#        ...
# 2341    NaN
# 2342    NaN
# 2343    NaN
# 2344    NaN
# 2346    NaN
# 2347    NaN
# 2350    NaN
# 2351    NaN
# 2352    NaN
# 2353    NaN
# 2354    NaN
# 2355    NaN
# 2356    NaN
# 2357    NaN
# 2358    NaN
# 2359    NaN
# 2360    NaN
# 2364    NaN
# 2365    NaN
# 2366    NaN
# 2367    NaN
# 2373    NaN
# 2374    NaN
# 2376    NaN
# 2377    NaN
# 2378    NaN
# 2379    NaN
# 2388    NaN
# 2389    NaN
# 2393    NaN
# Name: IBUs, Length: 2416, dtype: float64

# %%
df.IBUs.sort_values(na_position='last').hist(alpha=0.3, color='g')

# %% [markdown]
# ## Hmmmm, it looks like they are generally different styles. What are the most common 5 styles of high-IBU beer vs. low-IBU beer?
#
# - *Tip: You'll want to think about it in three pieces - filtering to only find the specific beers beers, then finding out what the most common styles are, then getting the top 5.*
# - *Tip: You CANNOT do this in one command. It's going to be one command for the high and one for the low.*
# - *Tip: "High IBU" means higher than 75th percentile, "Low IBU" is under 25th percentile*

# %%
df.dtypes
# Out:
# Beer         object
# Brewery      object
# Location     object
# Style        object
# Size         object
# ABV         float64
# IBUs        float64
# dtype: object

# %%
sorted_75 = df[df.IBUs>75]
sorted_75.Style.value_counts().sort_values(ascending=False).head(5)
# Out:
# American Double / Imperial IPA    66
# American IPA                      66
# American Black Ale                 9
# Russian Imperial Stout             5
# American Amber / Red Ale           4
# Name: Style, dtype: int64

# %%
sorted_25 = df[df.IBUs<25]
sorted_25.Style.value_counts().sort_values(ascending=False).tail(5)
# Out:
# English Dark Mild Ale    1
# American Strong Ale      1
# American Wild Ale        1
# Schwarzbier              1
# Belgian Dark Ale         1
# Name: Style, dtype: int64

# %% [markdown]
# ## Get the average IBU of "Witbier", "Hefeweizen" and "American Pale Wheat Ale" styles
#
# I'm counting these as wheat beers. If you see any other wheat beer categories, feel free to include them. I want ONE measurement and ONE graph, not three separate ones. And 20 to 30 bins in the histogram, please.
#
# - *Tip: I hope that `isin` is in your toolbox*

# %%
wheat_beers = df[df["Style"].isin(["Witbier","Hefeweizen","American Pale Wheat Ale"])]
wheat_beers.groupby(by='Style').IBUs.mean().hist(bins=20, alpha=0.5, color='m')

# %% [markdown]
# ## Draw a histogram of the IBUs of those beers

# %%
IPA=df[df['Beer'].str.contains("IPA", na=False)].Beer.value_counts().sort_values(ascending=False)
IPA
# Out:
# Dagger Falls IPA                                   3
# Green Monsta IPA                                   2
# Deviant Dale's IPA                                 2
# TailGate IPA                                       2
# Our Legacy IPA                                     2
# Point the Way IPA                                  2
# Long Hammer IPA                                    2
# Bitter Biker Double IPA                            2
# Tsunami IPA                                        2
# Hop Slayer Double IPA (2011)                       2
# Ranger IPA                                         2
# Gandhi-Bot Double IPA                              2
# CAPT Black IPA                                     2
# Lumberyard IPA                                     1
# Caldera IPA (2009)                                 1
# Hop Stalker Fresh Hop IPA                          1
# Point the Way IPA (2012)                           1
# Caldera IPA                                        1
# ...

# %% [markdown]
# ## Get the average IBU of any style with "IPA" in it (also draw a histogram)

# %%
sorted_IPA = df[df['Style'].str.contains("IPA", na=False)]
sorted_IPA.groupby(by='IBUs').mean().hist(alpha=0.3, color='r')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x15a27b860>]],
#       dtype=object)

# %% [markdown]
# ## Plot those two histograms on top of one another
#
# To plot two plots on top of one another, you do two steps.
#
# 1. First, you make a plot using `plot` or `hist`, and you save it into a variable called `ax`.
# 2. You draw your second graph using `plot` or `hist`, and send `ax=ax` to it as a parameter.
#
# It would look something like this:
#
# ```python
# ax = df.plot(....)
# df.plot(ax=ax, ....)
# ```
#
# (...except totally different)

# %%
df1= sorted_IPA.groupby(by='IBUs').mean()
df2 = wheat_beers.groupby(by='Style').IBUs.mean()
ax = df1.hist(alpha=0.3, color='r')
df1.hist(ax=ax, bins=20, alpha=0.5, color='m')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x15a31acc0>],
#       dtype=object)

# %% [markdown]
# ## Compare the ABV of wheat beers vs. IPAs : their IBUs were really different, but how about their alcohol percentage?
#
# Wheat beers might include witbier, hefeweizen, American Pale Wheat Ale, and anything else you think is wheaty. IPAs probably have "IPA" in their name.

# %%
wheat_beers = df[df["Style"].isin(["Witbier","Hefeweizen","American Pale Wheat Ale"])]
wheat_beers
# Out:
#                                       Beer                           Brewery  \
# 30                                    Park           Fort Point Beer Company
# 42                              Whitewater      Great Divide Brewing Company
# 72                             Citra Faced               Three Pints Brewing
# 112                           Summer Wheat            Anchor Brewing Company
# 138                            Waterkeeper        SweetWater Brewing Company
# 139                          Weissenheimer                   Destihl Brewery
# 142                          Beach Cruiser       Latitude 42 Brewing Company
# 164                         Pinata Protest          Freetail Brewing Company
# 167                                Rye Wit          Freetail Brewing Company
# 190                           Beach Patrol                    Brewery Vivant
# 195                                 Oberon                    Bell's Brewery
# ...

# %%
wheat_beers = df[df["Style"].isin(["Witbier","Hefeweizen","American Pale Wheat Ale"])]
wheat_beers.ABV.sort_values(ascending=True)
# Out:
# 1416    3.7
# 298     3.9
# 290     3.9
# 289     3.9
# 293     3.9
# 294     3.9
# 295     3.9
# 296     3.9
# 297     3.9
# 291     3.9
# 299     3.9
# 300     3.9
# 292     3.9
# 1738    4.0
# 1463    4.0
# 2004    4.1
# 719     4.2
# 2011    4.2
# 839     4.2
# 485     4.2
# 1555    4.2
# 1139    4.2
# 2161    4.2
# 2165    4.2
# 167     4.2
# 2263    4.2
# 551     4.3
# 1764    4.3
# 1744    4.4
# 1798    4.4
#        ...
# 686     5.8
# 195     5.8
# 2296    5.9
# 1452    5.9
# 771     5.9
# 328     5.9
# 637     6.0
# 555     6.0
# 164     6.0
# 1540    6.0
# 1323    6.0
# 1364    6.0
# 1547    6.1
# 42      6.1
# 397     6.1
# 1445    6.2
# 2172    6.2
# 225     6.5
# 190     6.5
# 522     6.8
# 889     7.0
# 898     7.9
# 2294    8.5
# 1845    8.5
# 1838    9.2
# 200     NaN
# 217     NaN
# 1553    NaN
# 1766    NaN
# 2063    NaN
# Name: ABV, Length: 188, dtype: float64

# %%
wheat_beers.ABV.sort_values(ascending=True).head(5)
# Out:
# 1416    3.7
# 298     3.9
# 290     3.9
# 289     3.9
# 293     3.9
# Name: ABV, dtype: float64

# %%
sorted_IPA.ABV.sort_values(ascending=True).head(5)
# Out:
# 1366    2.7
# 573     3.8
# 669     4.0
# 750     4.0
# 823     4.0
# Name: ABV, dtype: float64

# %%
wheat_beers.ABV.value_counts(normalize=True).sort_values(ascending=False).head(5)
#The ABV percentage of the selected wheat beers, which include witbier, hefeweizen, American Pale Wheat Ale.
# Out:
# 5.0    0.196721
# 4.7    0.092896
# 4.8    0.071038
# 5.2    0.065574
# 3.9    0.065574
# Name: ABV, dtype: float64

# %%
sorted_IPA.ABV.value_counts(normalize=True).sort_values(ascending=False).head(5)
#The ABV percentage of the beers with IPA on it
# Out:
# 7.0    0.110714
# 6.5    0.092857
# 6.2    0.067857
# 6.8    0.053571
# 6.0    0.051786
# Name: ABV, dtype: float64

# %% [markdown]
# ## Good work!
#
# If you made it this far you deserve a drink.
